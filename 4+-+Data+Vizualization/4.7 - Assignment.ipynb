# %%
# Import these libraries: Geopandas, Pandas and Matplotlip.pyplot & contextily

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> Read the Neighbourhood Data in the Assignment folder
#
#
# </div>

# %%
# Out:
#             NAME       LISTNAME        MAPNAME    Shape_Leng    Shape_Area  \
# 0     BRIDESBURG     Bridesburg     Bridesburg  27814.546521  4.458626e+07
# 1      BUSTLETON      Bustleton      Bustleton  48868.458365  1.140504e+08
# 2     CEDARBROOK     Cedarbrook     Cedarbrook  20021.415802  2.487174e+07
# 3  CHESTNUT_HILL  Chestnut Hill  Chestnut Hill  56394.297195  7.966498e+07
# 4     EAST_FALLS     East Falls     East Falls  27400.776417  4.057689e+07
#
#                                             geometry
# 0  POLYGON ((2719789.837 256235.538, 2719814.855 ...
# 1  POLYGON ((2733378.171 289259.945, 2732818.985 ...
# 2  POLYGON ((2685267.950 279747.336, 2685272.265 ...
# 3  POLYGON ((2678490.151 284400.400, 2678518.732 ...
# 4  POLYGON ((2686769.727 263625.367, 2686921.108 ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style='font-family:Georgia'> Read the Swimming Pool Dataset in the Assignment Folder
# </div>

# %%
# Out:
#    OBJECTID                 NAME                            PARK_NAME  \
# 0         1       Fox Chase Pool          Fox Chase Recreation Center
# 1         2        Mitchell Pool  Thomas Mitchell Memorial Playground
# 2         3          Jardel Pool      Thomas E. Jardel Memorial Field
# 3         4          Jacobs Pool             George Jacobs Playground
# 4         5  Morris Estates Pool        Morris Estate Cultural Center
#
#           ADDRESS_91  ZIP_CODE POOL_TYPE POOL_STATU  \
# 0   7901 RIDGEWAY ST     19111   OUTDOOR     ACTIVE
# 1  3600 WHITEHALL LN     19114   OUTDOOR     ACTIVE
# 2   1400 COTTMAN AVE     19111   OUTDOOR     ACTIVE
# 3    4500 LINDEN AVE     19136   OUTDOOR     ACTIVE
# 4   1610 CHELTEN AVE     19141   OUTDOOR     ACTIVE
#
#                                             COMMENTS  DATE_INSTA  \
# 0                                               None        None
# 1                                               None  2012-01-01
# 2                                               None        None
# 3                                               None        None
# 4  Emergency access is from Chelten around the bu...        None
#
#                   DATA_SOURC                    geometry
# 0  Finder; Previous GIS Data  POINT (-75.08232 40.07367)
# 1       Capital 2019; Finder  POINT (-74.99143 40.06830)
# 2  Finder; Previous GIS Data  POINT (-75.07590 40.05629)
# 3      Aquatics 2019; Finder  POINT (-75.00284 40.05266)
# 4     Finder; Administration  POINT (-75.14641 40.04992)

# %% [markdown]
# ## 1. Overlay Maps

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style='font-family:Georgia'> Create and Overlay Map of the two datasets (Neighbourhoods and swimming pools). Use Matplotlib fig, ax = plt.subplots and pass each ax to the two plots
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style='font-family:Georgia'> That was not the plot as we might have Excpected it. Can you think of a reason why this went wrong. Fix it (Hint: CRS)
# </div>

# %%
# Out:
# <Projected CRS: EPSG:2272>
# Name: NAD83 / Pennsylvania South (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: USA - Pennsylvania - SPCS - S
# - bounds: (-80.53, 39.71, -74.72, 41.18)
# Coordinate Operation:
# - name: SPCS83 Pennsylvania South zone (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> Reproject the pools data to the same CRS of the polygon data
# * <span style='font-family:Georgia'> Plot now the reprojected data and the polygons together.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> You might not see the Points. Hint all the points and the polygon data are all using Geopandas default color Blue. Change the color of both datasets to a color of your choice.
#
# </div>

# %% [markdown]
# ## 2. Add Basemaps

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> Create a the simming pool points map with a base map. Use Contextly. Do not forget to project the swimming pools datse to epsg 3857 to work properly with Contextly.
#
# * <span style='font-family:Georgia'> Hint (contextly has add_basemap), You might use Stamen TonerLite for your first basemap
#
# </div>

# %% [markdown]
# ## 3. Choropleth Map

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> Create a choropleth map from the Crime counts dataset we created in the last step of the 3.6 assignment.
#
# * <span style='font-family:Georgia'> You might copy the Geojson file we have created to your current folder
#
# </div>

# %%
# Out:
#             NAME       LISTNAME        MAPNAME    Shape_Leng    Shape_Area  \
# 0     BRIDESBURG     Bridesburg     Bridesburg  27814.546521  4.458626e+07
# 1      BUSTLETON      Bustleton      Bustleton  48868.458365  1.140504e+08
# 2     CEDARBROOK     Cedarbrook     Cedarbrook  20021.415802  2.487174e+07
# 3  CHESTNUT_HILL  Chestnut Hill  Chestnut Hill  56394.297195  7.966498e+07
# 4     EAST_FALLS     East Falls     East Falls  27400.776417  4.057689e+07
#
#    Counts                                           geometry
# 0     142  POLYGON ((2719789.837 256235.538, 2719814.855 ...
# 1     413  POLYGON ((2733378.171 289259.945, 2732818.985 ...
# 2     281  POLYGON ((2685267.950 279747.336, 2685272.265 ...
# 3     134  POLYGON ((2678490.151 284400.400, 2678518.732 ...
# 4     282  POLYGON ((2686769.727 263625.367, 2686921.108 ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> Create a Choropleth Map with the Counts Column
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> Normalize the Counts column with the Shape_are column. Divide the counts to the shape area and multiply with 100. Call the new column any name you want.
#
# </div>

# %%
# Out:
#             NAME       LISTNAME        MAPNAME    Shape_Leng    Shape_Area  \
# 0     BRIDESBURG     Bridesburg     Bridesburg  27814.546521  4.458626e+07
# 1      BUSTLETON      Bustleton      Bustleton  48868.458365  1.140504e+08
# 2     CEDARBROOK     Cedarbrook     Cedarbrook  20021.415802  2.487174e+07
# 3  CHESTNUT_HILL  Chestnut Hill  Chestnut Hill  56394.297195  7.966498e+07
# 4     EAST_FALLS     East Falls     East Falls  27400.776417  4.057689e+07
#
#    Counts                                           geometry  crime_norm
# 0     142  POLYGON ((2719789.837 256235.538, 2719814.855 ...    0.000003
# 1     413  POLYGON ((2733378.171 289259.945, 2732818.985 ...    0.000004
# 2     281  POLYGON ((2685267.950 279747.336, 2685272.265 ...    0.000011
# 3     134  POLYGON ((2678490.151 284400.400, 2678518.732 ...    0.000002
# 4     282  POLYGON ((2686769.727 263625.367, 2686921.108 ...    0.000007

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Instructions:</b>
#
#
# * <span style='font-family:Georgia'> Create a choropleth Map. Use the normalized column you have create above. Set legend=True to see the legend.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font size="50"><center><b font size="50">Good Job</b></font></center>
# </div>
